# %% [markdown]
# <a href="https://colab.research.google.com/github/ludo950/data-science-time-series/blob/main/Electric_production_forecast(LSTM%2C_SARIMA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project uses data related to the Electric Production from 1985 to 2017 and aims to develop ML algorithms for prediction and forecasting (SARIMAX and LSTM)<br>
# LSTM RMSE:  5.65<br>
# SARIMA RMSE : 4.2<br>
# LSTM MAPE : 11.25<br>
# SARIMA MAPE : 11.15<br>
#
# The results looks indeed very similar both in terms of rmse and mape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/datasets/Electric_Production.csv', index_col='DATE', parse_dates=True)

# %%
df.head()
# Out:
#               Value
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
df.tail()
# Out:
#                Value
# DATE
# 2017-09-01   98.6154
# 2017-10-01   93.6137
# 2017-11-01   97.3359
# 2017-12-01  114.7212
# 2018-01-01  129.4048

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 397 entries, 1985-01-01 to 2018-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   397 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
df.plot()

# %%
prediction_windows=12

# %%
train=df.iloc[:len(df)-prediction_windows]
test=df.iloc[len(df)-prediction_windows:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
n_input=12 #Use 12 months data to predict 13 th month data
n_features=1 #only one time series ! not multiple time series

# %%
X_train=[]
y_train=[]
for i in range(n_input,len(scaled_train)):
    X_train.append(scaled_train[i-n_input:i])
    y_train.append(scaled_train[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(f'Given the Array: \n {X_train[0].flatten()}')
print(f'Predict this y: \n {y_train[0]}')
# Out:
# Given the Array:
#  [0.24934943 0.22275812 0.10349754 0.03127801 0.         0.04025686
#  0.10596346 0.11507721 0.07643625 0.01450976 0.03895283 0.19436378]
# Predict this y:
#  [0.26096101]

# %%
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
# define model
model = Sequential()
model.add(LSTM(100, input_shape=(n_input, n_features), return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(100, input_shape=(n_input, n_features), return_sequences=False))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_26 (LSTM)               (None, 12, 100)           40800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 100)           0
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=150)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0038
# Epoch 2/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0030
# Epoch 3/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0037
# Epoch 4/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0035
# Epoch 5/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0031
# Epoch 6/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0033
# Epoch 7/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0034
# Epoch 8/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0035
# Epoch 9/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0031
# Epoch 10/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0033
# Epoch 11/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0028
# Epoch 12/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0028
# Epoch 13/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0029
# Epoch 14/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0030
# Epoch 15/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0034
# Epoch 16/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0031
# Epoch 17/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0037
# Epoch 18/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0042
# Epoch 19/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0042
# Epoch 20/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0036
# Epoch 21/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0038
# Epoch 22/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0031
# Epoch 23/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0031
# Epoch 24/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0030
# Epoch 25/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0030
# Epoch 26/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0029
# Epoch 27/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0028
# Epoch 28/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 29/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0031
# Epoch 30/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0032
# Epoch 31/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0032
# Epoch 32/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0028
# Epoch 33/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 34/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 35/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 36/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0028
# Epoch 37/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0028
# Epoch 38/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0027
# Epoch 39/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0028
# Epoch 40/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0029
# Epoch 41/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0026
# Epoch 42/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 43/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0029
# Epoch 44/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0028
# Epoch 45/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0026
# Epoch 46/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0029
# Epoch 47/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0030
# Epoch 48/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0027
# Epoch 49/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0029
# Epoch 50/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0025
# Epoch 51/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 52/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0024
# Epoch 53/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0023
# Epoch 54/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 55/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0027
# Epoch 56/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0023
# Epoch 57/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0025
# Epoch 58/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0026
# Epoch 59/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0031
# Epoch 60/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0025
# Epoch 61/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 62/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0029
# Epoch 63/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0024
# Epoch 64/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0025
# Epoch 65/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0025
# Epoch 66/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 67/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 68/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 69/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 70/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 71/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0021
# Epoch 72/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0025
# Epoch 73/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0026
# Epoch 74/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0026
# Epoch 75/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0025
# Epoch 76/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0031
# Epoch 77/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0025
# Epoch 78/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 79/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 80/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020
# Epoch 81/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 82/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 83/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0023
# Epoch 84/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 85/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 86/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 87/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0024
# Epoch 88/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 89/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0025
# Epoch 90/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 91/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 92/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020
# Epoch 93/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020
# Epoch 94/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 95/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 96/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0023
# Epoch 97/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0020
# Epoch 98/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0021
# Epoch 99/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 100/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0021
# Epoch 101/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020
# Epoch 102/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 103/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020
# Epoch 104/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0023
# Epoch 105/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0022
# Epoch 106/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0020
# Epoch 107/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 108/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0024
# Epoch 109/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 110/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 111/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0019
# Epoch 112/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 113/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0020
# Epoch 114/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 115/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0022
# Epoch 116/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 117/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 118/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020
# Epoch 119/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 120/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0018
# Epoch 121/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 122/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020
# Epoch 123/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0018
# Epoch 124/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 125/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020
# Epoch 126/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0018
# Epoch 127/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 128/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0021
# Epoch 129/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0024
# Epoch 130/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0026
# Epoch 131/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 132/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0019
# Epoch 133/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 134/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0024
# Epoch 135/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 136/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 137/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020
# Epoch 138/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 139/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0019
# Epoch 140/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0019
# Epoch 141/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0019
# Epoch 142/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0023
# Epoch 143/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0018
# Epoch 144/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020
# Epoch 145/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 146/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021
# Epoch 147/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 148/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0020
# Epoch 149/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0018
# Epoch 150/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:] # usa 12 input precedenti per predirre nuovo dato
current_batch=first_eval_batch.reshape((1,n_input,n_features)) # come visto sopra tipo (1,12,1)

for i in range(len(test)):
    #get the prediction alue for the first batch
    current_pred = model.predict(current_batch)[0]
    
    #append the prediction into the array
    test_predictions.append(current_pred)
    
    #use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test.plot(figsize=(14,5))

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_lstm=sqrt(mean_squared_error(test['Value'],test['Predictions']))
print(rmse_lstm)
# Out:
# 5.656331019072441

# %%
pred_dates=np.asarray(test.index)
dates=np.asarray(df.index)

# %%
plt.figure(figsize=(10,4))
plt.plot(pred_dates,test['Predictions'].values,color='red',label='Predicted')
plt.plot(dates,df.values, label='Real')
plt.legend()
plt.show()

# %%
mape_lstm=mape(df.values[-12:], test['Predictions'].values)
mape_lstm
# Out:
# 11.249284274240996

# %% [markdown]
# FORECAST

# %%
date_offset=12
forecast_dates =  (df.index + pd.DateOffset(months=date_offset))[-date_offset:]
forecast_dates
# Out:
# DatetimeIndex(['2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01',
#                '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01',
#                '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
forecast=[]

first_eval_batch = test_predictions[-n_input:] #use the past 12 values of the predicted values to forecast
current_batch=np.reshape(first_eval_batch,(1,n_input,n_features))

for i in range(date_offset):
    #get the prediction alue for the first batch
    current_pred = model.predict(current_batch)[0]
    
    #append the prediction into the array
    forecast.append(current_pred)
    
    #use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_forecast= scaler.inverse_transform(forecast)

# %%
df_forecast=pd.DataFrame({'date': forecast_dates})
df_forecast.set_index('date', inplace=True)
df_forecast['forecast']=true_forecast
df_forecast.head()
# Out:
#               forecast
# date
# 2018-02-01  111.075323
# 2018-03-01   99.675624
# 2018-04-01   90.077500
# 2018-05-01   92.391443
# 2018-06-01  107.202617

# %%
df_forecast.plot(figsize=(10,4))

# %%
plt.figure(figsize=(10,4))
plt.plot(dates,df.values, label='Real')
plt.plot(pred_dates,test['Predictions'].values,color='red',label='Predicted')
plt.plot(forecast_dates,df_forecast['forecast'].values, color='green', label='Forecast')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(dates[-12:],df[-12:].values, label='Real')
plt.plot(pred_dates,test['Predictions'].values,color='red',label='Predicted')
plt.plot(forecast_dates,df_forecast['forecast'].values, color='green', label='Forecast')
plt.legend()
plt.show()

# %% [markdown]
# # PREDICTION AND FORECASTING BY SARIMAX

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df)

fig = plt.figure()  
fig = result.plot()

# %%
from statsmodels.tsa.stattools import adfuller
result=adfuller(df.Value.dropna())
print(f'ADF Statistics:{result[0]}')
print(f'p-value:{result[1]}')
# Out:
# ADF Statistics:-2.256990350047245
# p-value:0.1862146911658677

# %%
result=adfuller(df.Value.diff().dropna())
print(f'ADF Statistics:{result[0]}')
print(f'p-value:{result[1]}')
# Out:
# ADF Statistics:-7.104890882267334
# p-value:4.0777865655388604e-10

# %% [markdown]
# Now the series looks stationary with a 1-order difference

# %% [markdown]
# ## ACF AND PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, (ax1, ax2)=plt.subplots(2,1,figsize=(8,8))

plot_acf(df,lags=14, zero=False, ax=ax1)
plot_pacf(df,lags=14, zero=False, ax=ax2)
plt.show()

# %% [markdown]
# The series looks indeed non stationary

# %% [markdown]
# ## AUTO ARIMA

# %%
# !pip install pmdarima
import pmdarima as pm
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.2)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)

# %%
results=pm.auto_arima(df, d=1, start_p=1, start_q=1, max_p=3, max_q=3,
                    seasonal=True, m=6, D=1, start_P=1, start_Q=1, max_P=2, max_Q=2, information_criterion='aic', trace=True, error_action='ignore', stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[6]             : AIC=1912.925, Time=0.75 sec
#  ARIMA(0,1,0)(0,1,0)[6]             : AIC=2404.500, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[6]             : AIC=1998.731, Time=0.18 sec
#  ARIMA(0,1,1)(0,1,1)[6]             : AIC=2057.803, Time=0.31 sec
#  ARIMA(1,1,1)(0,1,1)[6]             : AIC=2000.250, Time=0.58 sec
#  ARIMA(1,1,1)(1,1,0)[6]             : AIC=inf, Time=0.53 sec
#  ARIMA(1,1,1)(2,1,1)[6]             : AIC=1880.044, Time=1.17 sec
#  ARIMA(1,1,1)(2,1,0)[6]             : AIC=inf, Time=0.87 sec
#  ARIMA(1,1,1)(2,1,2)[6]             : AIC=inf, Time=2.74 sec
#  ARIMA(1,1,1)(1,1,2)[6]             : AIC=inf, Time=2.06 sec
#  ARIMA(0,1,1)(2,1,1)[6]             : AIC=1925.181, Time=0.80 sec
#  ARIMA(1,1,0)(2,1,1)[6]             : AIC=1942.791, Time=0.65 sec
#  ARIMA(2,1,1)(2,1,1)[6]             : AIC=1881.313, Time=1.81 sec
#  ARIMA(1,1,2)(2,1,1)[6]             : AIC=1880.682, Time=1.51 sec
#  ARIMA(0,1,0)(2,1,1)[6]             : AIC=1955.485, Time=0.54 sec
#  ARIMA(0,1,2)(2,1,1)[6]             : AIC=1887.170, Time=1.09 sec
#  ARIMA(2,1,0)(2,1,1)[6]             : AIC=1912.243, Time=0.96 sec
#  ARIMA(2,1,2)(2,1,1)[6]             : AIC=1879.804, Time=1.74 sec
#  ARIMA(2,1,2)(1,1,1)[6]             : AIC=1912.963, Time=0.98 sec
#  ARIMA(2,1,2)(2,1,0)[6]             : AIC=inf, Time=2.63 sec
#  ARIMA(2,1,2)(2,1,2)[6]             : AIC=inf, Time=3.63 sec
#  ARIMA(2,1,2)(1,1,0)[6]             : AIC=inf, Time=1.25 sec
#  ARIMA(2,1,2)(1,1,2)[6]             : AIC=1814.177, Time=3.34 sec
#  ARIMA(2,1,2)(0,1,2)[6]             : AIC=1952.465, Time=1.68 sec
#  ARIMA(2,1,2)(0,1,1)[6]             : AIC=1997.474, Time=0.88 sec
#  ARIMA(1,1,2)(1,1,2)[6]             : AIC=1814.373, Time=2.68 sec
#  ARIMA(2,1,1)(1,1,2)[6]             : AIC=1814.636, Time=2.42 sec
#  ARIMA(3,1,2)(1,1,2)[6]             : AIC=1815.095, Time=3.64 sec
#  ARIMA(2,1,3)(1,1,2)[6]             : AIC=1815.486, Time=4.38 sec
#  ARIMA(1,1,3)(1,1,2)[6]             : AIC=1815.064, Time=3.92 sec
#  ARIMA(3,1,1)(1,1,2)[6]             : AIC=1815.163, Time=3.22 sec
#  ARIMA(3,1,3)(1,1,2)[6]             : AIC=1816.736, Time=6.26 sec
#  ARIMA(2,1,2)(1,1,2)[6] intercept   : AIC=inf, Time=4.91 sec
#
# Best model:  ARIMA(2,1,2)(1,1,2)[6]
# Total fit time: 64.189 seconds

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(df,order=(2,1,2),  seasonal_order=(1, 1, 2, 6))
results=model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Value   No. Observations:                  397
# Model:             SARIMAX(2, 1, 2)x(1, 1, 2, 6)   Log Likelihood                -899.089
# Date:                           Fri, 10 Sep 2021   AIC                           1814.177
# Time:                                   14:55:15   BIC                           1845.907
# Sample:                               01-01-1985   HQIC                          1826.755
#                                     - 01-01-2018
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0873      0.350     -0.249      0.803      -0.773       0.599
# ar.L2          0.2828      0.214      1.321      0.187      -0.137       0.702
# ma.L1         -0.2982      0.337     -0.884      0.377      -0.959       0.363
# ma.L2         -0.6397      0.329     -1.944      0.052      -1.285       0.005
# ar.S.L6       -0.9976      0.003   -380.173      0.000      -1.003      -0.992
# ma.S.L6        0.1145      0.040      2.832      0.005       0.035       0.194
# ma.S.L12      -0.7764      0.037    -20.853      0.000      -0.849      -0.703
# sigma2         5.5549      0.307     18.092      0.000       4.953       6.157
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                42.26
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.75   Skew:                            -0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # ARIMA MODEL FIT

# %%
# Create the 4 diagostics plots
results.plot_diagnostics(figsize=(8,8))
plt.show()

# %% [markdown]
# # SARIMA PREDICTION

# %%
prediction = results.get_prediction(start=-12)
mean_prediction=prediction.predicted_mean

mean_prediction.size
# Out:
# 12

# %%
confi_int_p=prediction.conf_int()
lower_limits_p=confi_int_p.iloc[:,0]
upper_limits_p=confi_int_p.iloc[:,1]
confi_int_p.shape
# Out:
# (12, 2)

# %%
pred_dates=np.asarray(mean_prediction.index)
dates=np.asarray(df.index)

# %%
plt.figure(figsize=(10,4))
plt.plot(pred_dates,mean_prediction.values,color='red',label='prediction')
plt.fill_between(pred_dates, lower_limits_p, upper_limits_p, color='pink')
plt.plot(dates,df.values, label='real')
plt.legend()
plt.show()

# %%
mape_sarima = mape(df[-12:].values,mean_prediction.values)

# %%
rmse_sarima = sqrt(mean_squared_error(df[-12:].values,mean_prediction.values))
print(rmse_sarima)
# Out:
# 4.193259967100493

# %% [markdown]
# # SARIMA FORECAST

# %%
# Make ARIMA forecast of next 10 values
forecast = results.get_forecast(steps=12)
mean_forecast=forecast.predicted_mean
mean_forecast.size
# Out:
# 12

# %%
confi_int_f=forecast.conf_int()
lower_limits_f=confi_int_f.iloc[:,0]
upper_limits_f=confi_int_f.iloc[:,1]

# %%
forec_dates=np.asarray(mean_forecast.index)
pred_dates=np.asarray(mean_prediction.index)
dates=np.asarray(df.index)
plt.figure(figsize=(10,4))
plt.plot(forec_dates,mean_forecast.values,color='green',label='forecast')
plt.fill_between(forec_dates, lower_limits_f, upper_limits_f, color='lightgreen')

plt.plot(pred_dates,mean_prediction.values,color='red',label='prediction')
plt.fill_between(pred_dates, lower_limits_p, upper_limits_p, color='pink')

plt.plot(dates,df.values, label='real')
plt.legend(loc='upper left')
plt.show()

# %%
print('LSTM RMSE: ', rmse_lstm)
print('SARIMA RMSE :', rmse_sarima)
print('LSTM MAPE :', mape_lstm)
print('SARIMA MAPE :', mape_sarima)
# Out:
# LSTM RMSE:  5.656331019072441
# SARIMA RMSE : 4.193259967100493
# LSTM MAPE : 11.249284274240996
# SARIMA MAPE : 11.154561905289137

# %%
plt.figure(figsize=(10,4))
plt.plot(dates[-12:],df[-12:].values, label='Real') 
plt.plot(forec_dates,mean_forecast.values,color='#00ff00',label='SARIMA-Forecast')
plt.plot(pred_dates,mean_prediction.values,color='#ff0000',label='SARIMA-Prediction')
plt.plot(pred_dates,test['Predictions'].values,color='#ff9933',label='LSTM-Predicted')
plt.plot(forecast_dates,df_forecast['forecast'].values, color='#009933', label='LSTM-Forecast')
plt.legend(loc='upper left')
plt.show()
